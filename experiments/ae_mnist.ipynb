# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torch import nn
import torch.nn.functional as F
import torch.distributions as dists
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import transforms
from torchvision.datasets import MNIST

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

from models import *
import utils as ut

# %%
# dataset
transform = transforms.ToTensor()
dataset_train = MNIST(root='./data', train=True, transform=transform)
dataset_test = MNIST(root='./data', train=False, transform=transform)

# loader
len_batch = 32
loader_train = DataLoader(dataset_train, batch_size=len_batch, shuffle=True)
loader_test = DataLoader(dataset_test, batch_size=len_batch, shuffle=True)

# device
device = torch.device(f"cuda:{0}" if torch.cuda.is_available() else "cpu")

# model
model = AE_MNIST(2).to(device)

# optim
optimizer = torch.optim.Adam(model.parameters(), 
                             lr=1e-3, 
                             weight_decay=5e-4)

# estimation
loss = nn.BCELoss()

# %%
log = {
    'loss_train': [],
    'loss_test': [],
}

for epoch in range(100):
    # train
    lst_l = []
    for x, _ in loader_test:
        x = x.to(device)
        out = model(x)
        l = loss(out['x_'], x)
        optimizer.zero_grad()
        l.backward(retain_graph=True)
        optimizer.step()
        lst_l.append(l.item())
    log['loss_train'].append(np.mean(lst_l))
    # test
    lst_l = []
    with torch.no_grad():
        for x, _ in loader_test:
            x = x.to(device)
            out = model(x)
            l = loss(out['x_'], x)
            lst_l.append(l.item())
        
    log['loss_test'].append(np.mean(lst_l))
    # log
    print(
        f"epoch: {epoch+1}",
        f"train: {log['loss_train'][-1]: .5f}", 
        f"test: {log['loss_test'][-1]: .5f}")
    # plot
    if (epoch+1)%10 == 0:
        fig, ax = plt.subplots(1, 2)
        ax[0].imshow(x[0, 0].cpu())
        x_ = out['x_'].cpu().detach().reshape(-1, 1, 28, 28)
        ax[1].imshow(x_[0, 0])
        plt.show()
# Out:
# epoch: 1 train:  0.25195 test:  0.22340
# epoch: 2 train:  0.21875 test:  0.21485
# epoch: 3 train:  0.21469 test:  0.21242
# epoch: 4 train:  0.21126 test:  0.21008
# epoch: 5 train:  0.20903 test:  0.20962
# epoch: 6 train:  0.20756 test:  0.20736
# epoch: 7 train:  0.20640 test:  0.20493
# epoch: 8 train:  0.20557 test:  0.20405
# epoch: 9 train:  0.20464 test:  0.20468
# epoch: 10 train:  0.20367 test:  0.20481
# epoch: 11 train:  0.20239 test:  0.20142
# epoch: 12 train:  0.20176 test:  0.20140
# epoch: 13 train:  0.20103 test:  0.19940
# epoch: 14 train:  0.20063 test:  0.20152
# epoch: 15 train:  0.19955 test:  0.19952
# epoch: 16 train:  0.19967 test:  0.19878
# epoch: 17 train:  0.19833 test:  0.19694
# epoch: 18 train:  0.19838 test:  0.19980
# epoch: 19 train:  0.19772 test:  0.19769
# epoch: 20 train:  0.19762 test:  0.19592
# epoch: 21 train:  0.19743 test:  0.19802
# epoch: 22 train:  0.19727 test:  0.19571
# epoch: 23 train:  0.19679 test:  0.19545
# epoch: 24 train:  0.19640 test:  0.19862
# epoch: 25 train:  0.19673 test:  0.19462
# epoch: 26 train:  0.19620 test:  0.19564
# epoch: 27 train:  0.19601 test:  0.19607
# epoch: 28 train:  0.19557 test:  0.19556
# epoch: 29 train:  0.19548 test:  0.19430
# epoch: 30 train:  0.19511 test:  0.19532
# epoch: 31 train:  0.19524 test:  0.19682
# epoch: 32 train:  0.19518 test:  0.19642
# epoch: 33 train:  0.19515 test:  0.19455
# epoch: 34 train:  0.19503 test:  0.19428
# epoch: 35 train:  0.19489 test:  0.19552
# epoch: 36 train:  0.19460 test:  0.19364
# epoch: 37 train:  0.19487 test:  0.19446
# epoch: 38 train:  0.19454 test:  0.19420
# epoch: 39 train:  0.19427 test:  0.19285
# epoch: 40 train:  0.19403 test:  0.19371
# epoch: 41 train:  0.19388 test:  0.19396
# epoch: 42 train:  0.19409 test:  0.19355
# epoch: 43 train:  0.19388 test:  0.19353
# epoch: 44 train:  0.19405 test:  0.19364
# epoch: 45 train:  0.19394 test:  0.19400
# epoch: 46 train:  0.19355 test:  0.19383
# epoch: 47 train:  0.19352 test:  0.19263
# epoch: 48 train:  0.19366 test:  0.19268
# epoch: 49 train:  0.19353 test:  0.19318
# epoch: 50 train:  0.19348 test:  0.19396
# epoch: 51 train:  0.19333 test:  0.19266
# epoch: 52 train:  0.19347 test:  0.19190
# epoch: 53 train:  0.19318 test:  0.19331
# epoch: 54 train:  0.19304 test:  0.19377
# epoch: 55 train:  0.19329 test:  0.19308
# epoch: 56 train:  0.19319 test:  0.19169
# epoch: 57 train:  0.19310 test:  0.19223
# epoch: 58 train:  0.19310 test:  0.19230
# epoch: 59 train:  0.19296 test:  0.19214
# epoch: 60 train:  0.19296 test:  0.19322
# epoch: 61 train:  0.19252 test:  0.19238
# epoch: 62 train:  0.19252 test:  0.19376
# epoch: 63 train:  0.19273 test:  0.19195
# epoch: 64 train:  0.19272 test:  0.19241
# epoch: 65 train:  0.19249 test:  0.19242
# epoch: 66 train:  0.19271 test:  0.19236
# epoch: 67 train:  0.19243 test:  0.19172
# epoch: 68 train:  0.19248 test:  0.19286
# epoch: 69 train:  0.19261 test:  0.19416
# epoch: 70 train:  0.19233 test:  0.19321
# epoch: 71 train:  0.19214 test:  0.19253
# epoch: 72 train:  0.19237 test:  0.19377
# epoch: 73 train:  0.19259 test:  0.19151
# epoch: 74 train:  0.19229 test:  0.19260
# epoch: 75 train:  0.19215 test:  0.19143
# epoch: 76 train:  0.19219 test:  0.19141
# epoch: 77 train:  0.19202 test:  0.19208
# epoch: 78 train:  0.19217 test:  0.19148
# epoch: 79 train:  0.19230 test:  0.19133
# epoch: 80 train:  0.19202 test:  0.19211
# epoch: 81 train:  0.19215 test:  0.19134
# epoch: 82 train:  0.19199 test:  0.19219
# epoch: 83 train:  0.19211 test:  0.19171
# epoch: 84 train:  0.19218 test:  0.19261
# epoch: 85 train:  0.19191 test:  0.19239
# epoch: 86 train:  0.19210 test:  0.19153
# epoch: 87 train:  0.19203 test:  0.19092
# epoch: 88 train:  0.19195 test:  0.19146
# epoch: 89 train:  0.19196 test:  0.19130
# epoch: 90 train:  0.19190 test:  0.19252
# epoch: 91 train:  0.19177 test:  0.19107
# epoch: 92 train:  0.19199 test:  0.19143
# epoch: 93 train:  0.19191 test:  0.19289
# epoch: 94 train:  0.19148 test:  0.19224
# epoch: 95 train:  0.19160 test:  0.19181
# epoch: 96 train:  0.19190 test:  0.19024
# epoch: 97 train:  0.19163 test:  0.19081
# epoch: 98 train:  0.19162 test:  0.19041
# epoch: 99 train:  0.19157 test:  0.19158
# epoch: 100 train:  0.19162 test:  0.19217

# %%
# plot encoder decoder
fig, ax = plt.subplots(1, 2)
for i, (x, _) in enumerate(loader_test):
    ax[0].imshow(x[0, 0])
    x = x.to(device)
    x_ = model(x)['x_']
    x_ = x_.cpu().detach().reshape(-1, 1, 28, 28)
    ax[1].imshow(x_[0, 0])
    plt.show()
    break

# %%
# plot encoder
plt.figure(figsize=(10, 10))
for i, (x, y) in enumerate(loader_test):
    x = x.to(device)
    z = model.encode(x)
    z = z.cpu().detach()
    y = y.cpu()
    for label in range(10):
        idx = y == label
        plt.scatter(z[idx,0], z[idx,1])
    plt.legend(np.arange(10, dtype=np.int32))
plt.show()
